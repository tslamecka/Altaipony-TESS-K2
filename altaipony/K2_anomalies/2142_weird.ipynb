# %%
from altaipony.lcio import from_mast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# %matplotlib inline

# %%
df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\epic_catalogue.csv")
# Out:
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# C:\Users\thoma\AppData\Local\Temp\ipykernel_26880\3456439302.py:1: DeprecationWarning: invalid escape sequence '\V'
#   df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\epic_catalogue.csv")

# %%
df.loc[2142]
# Out:
# Unnamed: 0                         2142.000000
# EPIC ID                       228703128.000000
# Teff                               3544.962000
# logg                                  4.918200
# Flare #                              15.000000
# Observation time                     69.120736
# Average flare duration                0.358236
# Longest flare duration                1.511945
# Shortest flare duration               0.081727
# Average percentage increase         515.313325
# Highest percentage increase       14493.734741
# Lowest percentage increase       -14597.093201
# Name: 2142, dtype: float64

# %%
flc = from_mast("228703128", mode="LC", mission="K2")
# Out:
# 6% (163/2693) of the cadences will be ignored due to the quality mask (quality_bitmask=1130799).
# 6% (163/2693) of the cadences will be ignored due to the quality mask (quality_bitmask=1130799).

# %%
flc.plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
flc = flc.detrend("savgol")

# %%
plt.figure(figsize=(12,5))
plt.plot(flc.time.value, flc.flux / np.nanmedian(flc.flux), "r", label="PDCSAP_FLUX")
plt.plot(flc.time.value, flc.detrended_flux / np.nanmedian(flc.detrended_flux), "b.", label="detrended flux")
plt.xlabel("Time - 2457000 [BKJD days]")
plt.ylabel(r"Flux [e$^-$s$^{-1}$]")
#plt.xlim(2263, 2264)
#plt.ylim(.95,1.25)
plt.legend(loc=2,fontsize=13);

# %%
test.flares
# Out:
#    istart istop  cstart   cstop      tstart       tstop               ed_rec  \
# 0     700   704  130735  130739 2780.320258 2780.401984    959.3144690112408
# 1     846   855  130934  130944 2784.386167 2784.590483    89676.31085977543
# 2     901   918  131000  131018 2785.734658 2786.102428   1074681.1675632263
# 3    1024  1028  131155  131159 2788.901569 2788.983295   396.56630291113123
# 4    1184  1188  131395  131399 2793.805171 2793.886897   1310.6227954025394
# 5    1329  1371  131570  131617 2797.380714 2798.341003   -936024.4268185219
# 6    1388  1454  131641  131715 2798.831363 2800.343307   -560852.0819331704
# 7    1474  1504  131738  131771 2800.813236 2801.487482   -157972.3901442752
# 8    1520  1532  131796  131809 2801.998274 2802.263886     497489.529821086
# 9    1567  1574  131846  131855 2803.019859 2803.203744   115687.60458458468
# 10   1596  1608  131880  131893 2803.714537 2803.980149     343654.738425427
# 11   1854  1860  132182  132191 2809.884916 2810.068801  -1302810.5499404953
# 12   1929  1935  132267  132274 2811.621614 2811.764637    323818.6121800241
# 13   2090  2097  132470  132479 2815.769265 2815.953151  -35700.933059931165
# 14   2195  2203  132602  132611 2818.466264 2818.650151  -30761.329735656713
#
#             ed_rec_err             ampl_rec      dur  \
# 0   2.2805814444121184   0.1607884168624878 0.081727
# 1   12.864539835240082    15.07211685180664 0.204317
# 2   109.55471541694942   144.93734741210938 0.367770
# 3   1.8256818603407132  0.09564292430877686 0.081727
# 4   2.1902103539438538   0.2696082592010498 0.081727
# 5    67.25476130819247   -62.46632385253906 0.960289
# 6   41.166796323311154   -36.52735137939453 1.511945
# 7    19.41231079278683   -9.160889625549316 0.674246
# 8    47.36620748278015    65.31544494628906 0.265612
# 9    32.03885670996093   14.889728546142578 0.183885
# 10    42.2645961310402     47.1287727355957 0.265612
# 11   440.2573771648802  -145.97093200683594 0.183886
# 12   88.77482617324387    52.87760925292969 0.143022
# 13  12.096496239247548   -4.411601305007935 0.183886
# 14   8.103228884273074   -4.912962436676025 0.183887
#
#     total_n_valid_data_points
# 0                 2207.000000
# 1                 2207.000000
# 2                 2207.000000
# 3                 2207.000000
# 4                 2207.000000
# 5                 2207.000000
# 6                 2207.000000
# 7                 2207.000000
# 8                 2207.000000
# 9                 2207.000000
# 10                2207.000000
# 11                2207.000000
# 12                2207.000000
# 13                2207.000000
# 14                2207.000000

# %%
test = flc.find_flares(N1 = 3, N2 = 3, N3 = 4)
# Out:
# Found 0 candidate(s) in the (0,12) gap.
# Found 0 candidate(s) in the (12,64) gap.
# Found 0 candidate(s) in the (64,149) gap.
# Found 0 candidate(s) in the (149,165) gap.
# Found 0 candidate(s) in the (165,179) gap.
# Found 0 candidate(s) in the (179,199) gap.
# Found 0 candidate(s) in the (199,245) gap.
# Found 0 candidate(s) in the (245,277) gap.
# Found 0 candidate(s) in the (277,288) gap.
# Found 0 candidate(s) in the (288,326) gap.
# Found 0 candidate(s) in the (326,367) gap.
# Found 0 candidate(s) in the (367,432) gap.
# Found 0 candidate(s) in the (432,449) gap.
# Found 0 candidate(s) in the (449,477) gap.
# Found 1 candidate(s) in the (477,705) gap.
# Found 0 candidate(s) in the (705,745) gap.
# Found 0 candidate(s) in the (745,775) gap.
# Found 0 candidate(s) in the (775,804) gap.
# Found 1 candidate(s) in the (804,890) gap.
# Found 1 candidate(s) in the (890,926) gap.
# Found 0 candidate(s) in the (926,943) gap.
# Found 0 candidate(s) in the (943,1002) gap.
# Found 1 candidate(s) in the (1002,1031) gap.
# Found 0 candidate(s) in the (1031,1059) gap.
# Found 0 candidate(s) in the (1059,1074) gap.
# Found 0 candidate(s) in the (1074,1145) gap.
# Found 0 candidate(s) in the (1145,1162) gap.
# Found 1 candidate(s) in the (1162,1230) gap.
# Found 0 candidate(s) in the (1230,1322) gap.
# Found 1 candidate(s) in the (1322,1382) gap.
# Found 2 candidate(s) in the (1382,1505) gap.
# Found 3 candidate(s) in the (1505,1641) gap.
# Found 0 candidate(s) in the (1641,1668) gap.
# Found 0 candidate(s) in the (1668,1836) gap.
# Found 1 candidate(s) in the (1836,1886) gap.
# Found 1 candidate(s) in the (1886,1949) gap.
# Found 0 candidate(s) in the (1949,1969) gap.
# Found 0 candidate(s) in the (1969,1986) gap.
# Found 0 candidate(s) in the (1986,2055) gap.
# Found 0 candidate(s) in the (2055,2083) gap.
# Found 1 candidate(s) in the (2083,2109) gap.
# Found 0 candidate(s) in the (2109,2138) gap.
# Found 0 candidate(s) in the (2138,2165) gap.
# Found 1 candidate(s) in the (2165,2207) gap.
# C:\Users\thoma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\altaipony\altai.py:210: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   lc.flares = pd.concat([lc.flares, new], ignore_index=True)
