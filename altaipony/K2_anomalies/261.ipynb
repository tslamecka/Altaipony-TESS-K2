# %%
from altaipony.lcio import from_mast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# %matplotlib inline

# %%
df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\epic_catalogue.csv")
# Out:
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# C:\Users\thoma\AppData\Local\Temp\ipykernel_21428\3456439302.py:1: DeprecationWarning: invalid escape sequence '\V'
#   df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\epic_catalogue.csv")

# %%
df.loc[261]
# Out:
# EPIC ID                       228748525.000000
# Teff                               3516.509800
# logg                                  4.695500
# Flare #                              13.000000
# Observation time                     69.120680
# Average flare duration                0.303333
# Longest flare duration                1.654967
# Shortest flare duration               0.081728
# Average percentage increase         238.677445
# Highest percentage increase         747.371292
# Lowest percentage increase            1.498914
# Name: 261, dtype: float64

# %%
flc = from_mast("228748525", mode="LC", mission="K2")
# Out:
# 6% (163/2693) of the cadences will be ignored due to the quality mask (quality_bitmask=1130799).
# 6% (163/2693) of the cadences will be ignored due to the quality mask (quality_bitmask=1130799).

# %%
flc.plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
flc = flc.detrend("savgol")

# %%
plt.figure(figsize=(12,5))
plt.plot(flc.time.value, flc.flux / np.nanmedian(flc.flux), "r", label="PDCSAP_FLUX")
plt.plot(flc.time.value, flc.detrended_flux / np.nanmedian(flc.detrended_flux), "b.", label="detrended flux")
plt.xlabel("Time - 2457000 [BKJD days]")
plt.ylabel(r"Flux [e$^-$s$^{-1}$]")
plt.xlim(2750, 2751)
#plt.ylim(.95,1.2)
plt.legend(loc=2,fontsize=13);

# %%
flc.flares
# Out:
#    istart istop  cstart   cstop      tstart       tstop              ed_rec  \
# 0      45    50  129283  129288 2750.652737 2750.754897   2544.762740375606
# 1      66    78  129308  129320 2751.163537 2751.408720  11362.593163052812
# 2     158   169  129419  129435 2753.431485 2753.758396  17331.864499663963
# 3     191   195  129462  129466 2754.310059 2754.391786   626.7215861851155
# 4     492   521  130508  130537 2775.681717 2776.274236  122822.70255771208
# 5     628   708  130646  130727 2778.501291 2780.156258   689925.8346050995
# 6     947   952  131038  131043 2786.510510 2786.612669  1917.3318209833415
# 7    1068  1075  131215  131222 2790.126917 2790.269938   5257.648735277012
# 8    1240  1244  131487  131492 2795.684334 2795.786493  62.726727070454295
# 9    1299  1310  131695  131707 2799.934128 2800.179309    24973.1201905239
# 10   1331  1335  131798  131803 2802.038595 2802.140754   22796.12519863141
# 11   1391  1395  131882  131887 2803.754861 2803.857019  11448.501162404535
# 12   1592  1596  132230  132237 2810.865118 2811.008140  2334.8023669071017
#
#             ed_rec_err              ampl_rec      dur  \
# 0   1.8960043970341183    0.5981413125991821 0.102160
# 1    3.008845646646179    1.3372840881347656 0.245184
# 2    5.491907088210945    2.0535879135131836 0.326911
# 3   2.3126069595700898     0.177068829536438 0.081728
# 4   22.849199114607252     6.488725185394287 0.592519
# 5    43.25110763186788     7.473712921142578 1.654967
# 6   1.7835036208399635    0.4089392423629761 0.102158
# 7    2.063443961503911    0.6537008285522461 0.143022
# 8   1.3485859715953568  0.014989137649536133 0.102159
# 9   1.2198939238916862     4.875596046447754 0.245181
# 10  1.2605947418970802     4.303979873657227 0.102159
# 11  1.1075586532965107    2.4077553749084473 0.102159
# 12   4.447523986500236   0.23458707332611084 0.143023
#
#     total_n_valid_data_points
# 0                 1750.000000
# 1                 1750.000000
# 2                 1750.000000
# 3                 1750.000000
# 4                 1750.000000
# 5                 1750.000000
# 6                 1750.000000
# 7                 1750.000000
# 8                 1750.000000
# 9                 1750.000000
# 10                1750.000000
# 11                1750.000000
# 12                1750.000000

# %%
flc = flc.find_flares(N1=3, N2=3, N3=4)
# Out:
# Found 0 candidate(s) in the (0,11) gap.
# Found 1 candidate(s) in the (11,65) gap.
# Found 1 candidate(s) in the (65,106) gap.
# Found 0 candidate(s) in the (106,124) gap.
# Found 0 candidate(s) in the (124,143) gap.
# Found 1 candidate(s) in the (143,178) gap.
# Found 1 candidate(s) in the (178,197) gap.
# Found 0 candidate(s) in the (197,216) gap.
# Found 0 candidate(s) in the (216,242) gap.
# Found 0 candidate(s) in the (242,283) gap.
# Found 0 candidate(s) in the (283,321) gap.
# Found 0 candidate(s) in the (321,433) gap.
# Found 0 candidate(s) in the (433,452) gap.
# Found 0 candidate(s) in the (452,491) gap.
# Found 2 candidate(s) in the (491,709) gap.
# Found 0 candidate(s) in the (709,784) gap.
# Found 0 candidate(s) in the (784,834) gap.
# Found 0 candidate(s) in the (834,852) gap.
# Found 0 candidate(s) in the (852,869) gap.
# Found 0 candidate(s) in the (869,923) gap.
# Found 1 candidate(s) in the (923,962) gap.
# Found 0 candidate(s) in the (962,976) gap.
# Found 0 candidate(s) in the (976,995) gap.
# Found 1 candidate(s) in the (995,1082) gap.
# Found 0 candidate(s) in the (1082,1160) gap.
# Found 0 candidate(s) in the (1160,1176) gap.
# Found 0 candidate(s) in the (1176,1214) gap.
# Found 0 candidate(s) in the (1214,1232) gap.
# Found 1 candidate(s) in the (1232,1263) gap.
# Found 0 candidate(s) in the (1263,1282) gap.
# Found 0 candidate(s) in the (1282,1298) gap.
# Found 1 candidate(s) in the (1298,1315) gap.
# Found 1 candidate(s) in the (1315,1375) gap.
# Found 1 candidate(s) in the (1375,1400) gap.
# Found 0 candidate(s) in the (1400,1417) gap.
# Found 0 candidate(s) in the (1417,1444) gap.
# Found 0 candidate(s) in the (1444,1493) gap.
# Found 0 candidate(s) in the (1493,1507) gap.
# Found 0 candidate(s) in the (1507,1558) gap.
# Found 0 candidate(s) in the (1558,1586) gap.
# Found 1 candidate(s) in the (1586,1599) gap.
# Found 0 candidate(s) in the (1599,1616) gap.
# Found 0 candidate(s) in the (1616,1655) gap.
# Found 0 candidate(s) in the (1655,1668) gap.
# Found 0 candidate(s) in the (1668,1685) gap.
# Found 0 candidate(s) in the (1685,1702) gap.
# Found 0 candidate(s) in the (1702,1719) gap.
# Found 0 candidate(s) in the (1719,1750) gap.
# C:\Users\thoma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\altaipony\altai.py:210: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   lc.flares = pd.concat([lc.flares, new], ignore_index=True)
