# %%
from altaipony.lcio import from_mast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.5f' % x)
# %matplotlib inline

# %%
dfk = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\K2_catalogue_degrees.csv")
dft = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\TESS_catalogue_degrees_cut.csv")
# Out:
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# <>:2: DeprecationWarning: invalid escape sequence '\V'
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# <>:2: DeprecationWarning: invalid escape sequence '\V'
# C:\Users\thoma\AppData\Local\Temp\ipykernel_13360\964684316.py:1: DeprecationWarning: invalid escape sequence '\V'
#   dfk = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\K2_catalogue_degrees.csv")
# C:\Users\thoma\AppData\Local\Temp\ipykernel_13360\964684316.py:2: DeprecationWarning: invalid escape sequence '\V'
#   dft = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\TESS_catalogue_degrees_cut.csv")

# %%
dfk.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
dft = dft.drop(dft.columns[-1], axis=1)

# %%
dfk
# Out:
#         EPIC ID       Teff    logg  Flare #  Observation time  \
# 0     248526013 4142.83740 4.63070  3.00000          79.66369
# 1     213508874 4212.15970 4.46730  5.00000          81.33884
# 2     220231988 4036.32060 4.62530  4.00000          78.68262
# 3     245921548 4233.24300 4.54960 34.00000          78.86645
# 4     246773415 4128.93260 4.37020  2.00000          80.54210
# ...         ...        ...     ...      ...               ...
# 3237  220231660 3876.68650 4.79620  4.00000          78.68262
# 3238  248474210 3344.35230 4.89570  1.00000          79.66382
# 3239  220222734 3989.65600 4.78130  2.00000          78.68268
# 3240  245944800 4232.94600 4.76100  1.00000          78.86638
# 3241  201217829 3601.87040 4.63060  0.00000          79.97015
#
#       Average flare duration  Longest flare duration  Shortest flare duration  \
# 0                    0.16346                 0.18389                  0.14302
# ...

# %%
columns = ['Unnamed: 0', 'TIC ID', 'Teff', 'logg', 'Flare #', 'Observation time', 'Average flare durartion', 'Longest flare duration', 'Shortest flare duration', 'Average percentage increase', 'Highest percentage increase', 'Lowest percentage increase', 'Flares per hour', 'Flares per day', 'RA', 'Dec']
empty = pd.DataFrame(columns = columns, index = range(2150, 3242))
dft = pd.concat([dft, empty])
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_13360\3761300787.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dft = pd.concat([dft, empty])

# %%
def remove_last_decimal(x):
    if pd.notnull(x):
        return int(x * 10**5) / 10**5
    else:
        return x

# %%
dft['Dec'] = dft['Dec'].apply(remove_last_decimal)

# %%
dft.to_csv("C:\Vs_code_projects\mdwarf_flares\TESS_catalogue_degrees_cut.csv", index = False)
# Out:
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# C:\Users\thoma\AppData\Local\Temp\ipykernel_13360\2147527219.py:1: DeprecationWarning: invalid escape sequence '\V'
#   dft.to_csv("C:\Vs_code_projects\mdwarf_flares\TESS_catalogue_degrees_cut.csv", index = False)

# %%
for i in len()
