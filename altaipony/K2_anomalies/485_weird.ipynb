# %%
from altaipony.lcio import from_mast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# %matplotlib inline

# %%
df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\epic_catalogue.csv")
# Out:
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# C:\Users\thoma\AppData\Local\Temp\ipykernel_10592\3456439302.py:1: DeprecationWarning: invalid escape sequence '\V'
#   df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\epic_catalogue.csv")

# %%
df.loc[485]
# Out:
# Unnamed: 0                          485.000000
# EPIC ID                       203072076.000000
# Teff                               3356.797600
# logg                                  4.770800
# Flare #                               5.000000
# Observation time                     59.844639
# Average flare duration                0.118504
# Longest flare duration                0.183885
# Shortest flare duration               0.081726
# Average percentage increase          42.122092
# Highest percentage increase         122.454262
# Lowest percentage increase            7.717729
# Name: 485, dtype: float64

# %%
flc = from_mast("203072076", mode="LC", mission="K2")
# Out:
# Warning: 36% (1374/3850) of the cadences will be ignored due to the quality mask (quality_bitmask=1130799).
# Warning: 36% (1374/3850) of the cadences will be ignored due to the quality mask (quality_bitmask=1130799).

# %%
flc.plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
flc = flc.detrend("savgol")

# %%
plt.figure(figsize=(12,5))
plt.plot(flc.time.value, flc.flux / np.nanmedian(flc.flux), "r", label="PDCSAP_FLUX")
plt.plot(flc.time.value, flc.detrended_flux / np.nanmedian(flc.detrended_flux), "b.", label="detrended flux")
plt.xlabel("Time - 2457000 [BKJD days]")
plt.ylabel(r"Flux [e$^-$s$^{-1}$]")
plt.xlim(2084, 2086)
#plt.ylim(.95,1.2)
plt.legend(loc=2,fontsize=13);

# %%
test.flares
# Out:
#   istart istop cstart  cstop      tstart       tstop              ed_rec  \
# 0   1073  1077  96693  96698 2084.720630 2084.822789   2053.295138550833
# 1   1105  1111  96727  96734 2085.415310 2085.558332   4430.319374088409
# 2   1477  1481  97118  97122 2093.404107 2093.485834  227.16187403427335
# 3   2017  2021  97888  97892 2109.136470 2109.218197  315.54669738137363
# 4   2128  2134  98116  98125 2113.794882 2113.978767   553.8335148234339
#
#            ed_rec_err             ampl_rec      dur  total_n_valid_data_points
# 0   5.629515553383566   0.5626829862594604 0.102159                2225.000000
# 1   5.603397720885702   1.2245426177978516 0.143022                2225.000000
# 2  3.8889689367631743  0.08780908584594727 0.081727                2225.000000
# 3   2.780224147329109   0.1538926362991333 0.081726                2225.000000
# 4  6.8330366886791145  0.07717728614807129 0.183885                2225.000000

# %%
test = flc.find_flares(N1 = 3, N2 = 3, N3 = 4)
# Out:
# Found 0 candidate(s) in the (0,143) gap.
# Found 3 candidate(s) in the (143,1692) gap.
# Found 0 candidate(s) in the (1692,1762) gap.
# Found 0 candidate(s) in the (1762,1777) gap.
# Found 0 candidate(s) in the (1777,1857) gap.
# Found 0 candidate(s) in the (1857,1890) gap.
# Found 0 candidate(s) in the (1890,1938) gap.
# Found 0 candidate(s) in the (1938,1954) gap.
# Found 0 candidate(s) in the (1954,1995) gap.
# Found 1 candidate(s) in the (1995,2032) gap.
# Found 0 candidate(s) in the (2032,2080) gap.
# Found 0 candidate(s) in the (2080,2113) gap.
# Found 1 candidate(s) in the (2113,2152) gap.
# Found 0 candidate(s) in the (2152,2169) gap.
# Found 0 candidate(s) in the (2169,2181) gap.
# Found 0 candidate(s) in the (2181,2201) gap.
# Found 0 candidate(s) in the (2201,2225) gap.
# C:\Users\thoma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\altaipony\altai.py:210: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   lc.flares = pd.concat([lc.flares, new], ignore_index=True)
