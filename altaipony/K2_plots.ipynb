# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from matplotlib import rcParams

rcParams['font.family'] = 'serif'
rcParams['mathtext.default'] = 'regular'
plt.rcParams.update({'font.size':10})

plt.rcParams['xtick.major.size'] = 8  # Length of major x-ticks
plt.rcParams['xtick.minor.size'] = 4   # Length of minor x-ticks
plt.rcParams['ytick.major.size'] = 8  # Length of major y-ticks
plt.rcParams['ytick.minor.size'] = 4   # Length of minor y-ticks
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_23020\1394600617.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\K2_catalogues\K2_catalogue_cut_revised.csv")

# %%
df_revised = df[df["Lowest percentage increase"] >= 0]

# %%
plt.figure(figsize=(10, 5), dpi = 200)
plt.scatter(df['Average percentage increase'], df['Flare #'], c = "mediumpurple", edgecolor = "black", s = 25, label = "K2")
plt.xscale('log')
plt.xlabel("Average Percentage Increase")
plt.ylabel("Number of Flares")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5), dpi = 200)
plt.scatter(df['Teff'], df['Flare #'], c = "mediumpurple", edgecolor = "black", s = 25)
plt.xlabel("Effective Temperature (K)")
plt.ylabel("Number of Flares")
#plt.ticklabel_format(style = "sci", axis = "y", scilimits = (0,0)) 
plt.show()

# %%
plt.figure(figsize=(10, 5), dpi = 200)
plt.scatter(df['logg'], df['Flare #'], c = "mediumpurple", edgecolor = "black", s = 25)
plt.xlabel("log g")
plt.ylabel("Number of Flares")
plt.show()

# %%
plt.figure(figsize=(10, 5), dpi = 200)
plt.scatter(df['Teff'], df['Average percentage increase'], c = "mediumpurple", edgecolor = "black", s = 25)
plt.xlabel("Effective Temperature (K)")
plt.ylabel("Average Percentage Increase")
plt.yscale("log")
plt.show()

# %%
plt.figure(figsize=(10, 5), dpi = 200)
plt.scatter(df['logg'], df_revised['Average percentage increase'], c = "mediumpurple", edgecolor = "black", s = 25)
plt.xlabel("log g")
plt.ylabel("Average Percentage Increase")
plt.yscale("log")
plt.show()
