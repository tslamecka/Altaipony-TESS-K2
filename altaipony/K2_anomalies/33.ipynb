# %%
from altaipony.lcio import from_mast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# %matplotlib inline

# %%
df.loc[33]
# Out:
# EPIC ID                       202787821.000000
# Teff                               3590.609400
# logg                                  4.047700
# Flare #                               3.000000
# Observation time                     59.844729
# Average flare duration                0.217938
# Longest flare duration                0.265612
# Shortest flare duration               0.143023
# Average percentage increase          73.921025
# Highest percentage increase         171.214771
# Lowest percentage increase           17.392862
# Name: 33, dtype: float64

# %%
df['EPIC ID'][33]
# Out:
# 202787821

# %%
flc = from_mast("202787821", mode="LC", mission="K2")

# %%
flc.plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
plt.figure(figsize=(12,5))
#plt.plot(flc.time.value, flc.flux / np.nanmedian(flc.flux)+0.1, c="r", label="PDCSAP_FLUX")
plt.plot(flc.time.value, flc.detrended_flux / np.nanmedian(flc.detrended_flux), "b.", label="detrended flux")
plt.xlabel("Time - 2457000 [BKJD days]")
plt.ylabel(r"Flux [e$^-$s$^{-1}$]")
plt.xlim(2080, 2084.2)
#plt.ylim(.95,1.2)
plt.legend(loc=2,fontsize=13);

# %%
test.flares
# Out:
#   istart istop cstart  cstop      tstart       tstop              ed_rec  \
# 0   1034  1041  96656  96663 2083.964983 2084.108006   4903.025261363098
# 1   1545  1556  97202  97215 2095.120715 2095.386327  1608.5223692988347
# 2   2138  2148  98248  98260 2116.492211 2116.737391  1325.1230479991084
#
#            ed_rec_err            ampl_rec      dur  total_n_valid_data_points
# 0  0.6717836079808037  1.7121477127075195 0.143023                2210.000000
# 1  0.7656320251254956  0.3315544128417969 0.265612                2210.000000
# 2  0.9217397307860626  0.1739286184310913 0.245179                2210.000000

# %%
flc = flc.detrend("savgol")

# %%
flc = flc.find_flares(N1 = 4, N2 = 4, N3 = 6)
# Out:
# Found 0 candidate(s) in the (0,143) gap.
# Found 1 candidate(s) in the (143,1042) gap.
# Found 1 candidate(s) in the (1042,1557) gap.
# Found 0 candidate(s) in the (1557,1678) gap.
# Found 0 candidate(s) in the (1678,1748) gap.
# Found 0 candidate(s) in the (1748,1763) gap.
# Found 0 candidate(s) in the (1763,1843) gap.
# Found 0 candidate(s) in the (1843,1876) gap.
# Found 0 candidate(s) in the (1876,1924) gap.
# Found 0 candidate(s) in the (1924,1940) gap.
# Found 0 candidate(s) in the (1940,1980) gap.
# Found 0 candidate(s) in the (1980,2017) gap.
# Found 0 candidate(s) in the (2017,2065) gap.
# Found 0 candidate(s) in the (2065,2098) gap.
# Found 0 candidate(s) in the (2098,2137) gap.
# Found 1 candidate(s) in the (2137,2154) gap.
# Found 0 candidate(s) in the (2154,2166) gap.
# Found 0 candidate(s) in the (2166,2186) gap.
# Found 0 candidate(s) in the (2186,2210) gap.
# ...
