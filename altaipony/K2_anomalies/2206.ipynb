# %%
from altaipony.lcio import from_mast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# %matplotlib inline

# %%
df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\epic_catalogue.csv")
# Out:
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# C:\Users\thoma\AppData\Local\Temp\ipykernel_22584\3456439302.py:1: DeprecationWarning: invalid escape sequence '\V'
#   df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\epic_catalogue.csv")

# %%
df.loc[2206]
# Out:
# Unnamed: 0                         2206.000000
# EPIC ID                       213415045.000000
# Teff                               3207.864700
# logg                                  4.981900
# Flare #                               3.000000
# Observation time                     81.338936
# Average flare duration                0.136211
# Longest flare duration                0.204316
# Shortest flare duration               0.102158
# Average percentage increase         185.739875
# Highest percentage increase         535.220575
# Lowest percentage increase            4.010963
# Name: 2206, dtype: float64

# %%
flc = from_mast("213415045", mode="LC", mission="K2")
# Out:
# 15% (588/4037) of the cadences will be ignored due to the quality mask (quality_bitmask=1130799).
# 15% (588/4037) of the cadences will be ignored due to the quality mask (quality_bitmask=1130799).

# %%
flc.plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
flc = flc.detrend("savgol")

# %%
plt.figure(figsize=(12,5))
plt.plot(flc.time.value, flc.flux / np.nanmedian(flc.flux), "r", label="PDCSAP_FLUX")
plt.plot(flc.time.value, flc.detrended_flux / np.nanmedian(flc.detrended_flux), "b.", label="detrended flux")
plt.xlabel("Time - 2457000 [BKJD days]")
plt.ylabel(r"Flux [e$^-$s$^{-1}$]")
plt.xlim(2534, 2536)
#plt.ylim(.95,1.25)
plt.legend(loc=2,fontsize=13);

# %%
test.flares
# Out:
#   istart istop  cstart   cstop      tstart       tstop             ed_rec  \
# 0   2737  2746  118728  118738 2534.971694 2535.176010  15857.28482280682
# 1   2970  2975  119029  119034 2541.121620 2541.223779  619.5888752318147
# 2   3263  3267  119379  119384 2548.272723 2548.374882  269.4314926203586
#
#            ed_rec_err             ampl_rec      dur  total_n_valid_data_points
# 0  16.957492386264356    5.352205753326416 0.204316                3325.000000
# 1  18.831508226500645  0.17988085746765137 0.102158                3325.000000
# 2  26.985621544615487  0.04010963439941406 0.102159                3325.000000

# %%
test = flc.find_flares(N1 = 3, N2 = 3, N3 = 4)
# Out:
# Found 0 candidate(s) in the (0,79) gap.
# Found 0 candidate(s) in the (79,1758) gap.
# Found 0 candidate(s) in the (1758,2278) gap.
# Found 0 candidate(s) in the (2278,2338) gap.
# Found 0 candidate(s) in the (2338,2352) gap.
# Found 0 candidate(s) in the (2352,2399) gap.
# Found 0 candidate(s) in the (2399,2427) gap.
# Found 0 candidate(s) in the (2427,2478) gap.
# Found 0 candidate(s) in the (2478,2529) gap.
# Found 0 candidate(s) in the (2529,2545) gap.
# Found 0 candidate(s) in the (2545,2573) gap.
# Found 0 candidate(s) in the (2573,2631) gap.
# Found 0 candidate(s) in the (2631,2681) gap.
# Found 0 candidate(s) in the (2681,2695) gap.
# Found 0 candidate(s) in the (2695,2723) gap.
# Found 1 candidate(s) in the (2723,2749) gap.
# Found 0 candidate(s) in the (2749,2765) gap.
# Found 0 candidate(s) in the (2765,2805) gap.
# Found 0 candidate(s) in the (2805,2832) gap.
# Found 0 candidate(s) in the (2832,2861) gap.
# Found 0 candidate(s) in the (2861,2900) gap.
# Found 1 candidate(s) in the (2900,3003) gap.
# Found 0 candidate(s) in the (3003,3063) gap.
# Found 0 candidate(s) in the (3063,3144) gap.
# Found 0 candidate(s) in the (3144,3236) gap.
# Found 1 candidate(s) in the (3236,3304) gap.
# Found 0 candidate(s) in the (3304,3325) gap.
# C:\Users\thoma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\altaipony\altai.py:210: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   lc.flares = pd.concat([lc.flares, new], ignore_index=True)
