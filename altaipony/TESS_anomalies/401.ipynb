# %%
from altaipony.lcio import from_mast
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.6f' % x)
# %matplotlib inline

# %%
df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\TESS_catalogue_revised.csv")
# Out:
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# <>:1: DeprecationWarning: invalid escape sequence '\V'
# C:\Users\thoma\AppData\Local\Temp\ipykernel_9068\3915017766.py:1: DeprecationWarning: invalid escape sequence '\V'
#   df = pd.read_csv("C:\Vs_code_projects\mdwarf_flares\TESS_catalogue_revised.csv")

# %%
flc = from_mast("TIC 243010858", mode="LC", mission="TESS")
# Out:
# 1% (8/1196) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 1% (8/1196) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 0% (11/3600) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 0% (11/3600) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 2% (88/3534) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 2% (88/3534) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 0% (12/3408) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 0% (12/3408) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 1% (17/3278) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# 1% (17/3278) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# ...

# %%
flc_0 = flc[0]
flc_1 = flc[1]
flc_2 = flc[2]
flc_3 = flc[3]
flc_4 = flc[4]
flc_5 = flc[5]
flc_6 = flc[6]

# %%
flc_0.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
flc_1.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
flc_2.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
flc_3.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
flc_4.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
flc_5.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
flc_6.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
flc_0 = flc_0.detrend("savgol")
flc_1 = flc_1.detrend("savgol")
flc_2 = flc_2.detrend("savgol")
flc_3 = flc_3.detrend("savgol")
flc_4 = flc_4.detrend("savgol")
flc_5 = flc_5.detrend("savgol")
flc_6 = flc_6.detrend("savgol")

# %%
plt.figure(figsize=(12,5))

plt.plot(flc_6.time.value, flc_6.flux, "r", label="PDCSAP_FLUX")
plt.plot(flc_6.time.value, flc_6.detrended_flux, "b.", label="detrended flux")

plt.xlabel("Time - 2457000 [BKJD days]")
plt.ylabel(r"Flux [e$^-$s$^{-1}$]")

plt.xlim(1463, 1464)
#plt.ylim(.95,1.25)

plt.legend(loc=2,fontsize=13);

# %%
flares_6.flares
# Out:
#   istart istop cstart  cstop      tstart       tstop              ed_rec  \
# 0    577   581  10686  10690 1450.099970 1450.183302  -767575.6110100232
# 1   1159  1170  11338  11349 1463.683039 1463.912198   5491708277.343455
#
#            ed_rec_err             ampl_rec      dur  total_n_valid_data_points
# 0   42616.71733137645  -184.32658003085794 0.083333                1174.000000
# 1  15034500.352753239   1935113.5594882984 0.229159                1174.000000

# %%
flares_0 = flc_0.find_flares(N1 = 3, N2 = 3, N3 = 4)
flares_1 = flc_1.find_flares(N1 = 3, N2 = 3, N3 = 4)
flares_2 = flc_2.find_flares(N1 = 3, N2 = 3, N3 = 4)
flares_3 = flc_3.find_flares(N1 = 3, N2 = 3, N3 = 4)
flares_4 = flc_4.find_flares(N1 = 3, N2 = 3, N3 = 4)
flares_5 = flc_5.find_flares(N1 = 3, N2 = 3, N3 = 4)
flares_6 = flc_6.find_flares(N1 = 3, N2 = 3, N3 = 4)
# Out:
# Found 1 candidate(s) in the (0,582) gap.
# Found 1 candidate(s) in the (582,1178) gap.
# C:\Users\thoma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\altaipony\altai.py:210: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   lc.flares = pd.concat([lc.flares, new], ignore_index=True)
# Found 1 candidate(s) in the (0,1663) gap.
# Found 1 candidate(s) in the (1663,3571) gap.
# ...
